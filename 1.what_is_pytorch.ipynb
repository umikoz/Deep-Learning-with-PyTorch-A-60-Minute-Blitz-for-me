# %% [markdown]
# http://pytorch.org/tutorials/beginner/blitz/tensor_tutorial.html#sphx-glr-beginner-blitz-tensor-tutorial-py

# %%
import torch

# %%
x = torch.Tensor(5,3)

# %%
x
# Out:
# -6.4186e+26  4.5864e-41 -6.4186e+26
#  4.5864e-41  0.0000e+00  0.0000e+00
#  0.0000e+00  0.0000e+00  0.0000e+00
#  0.0000e+00  0.0000e+00  0.0000e+00
#  0.0000e+00  0.0000e+00  0.0000e+00
# [torch.FloatTensor of size 5x3]

# %%
x = torch.rand(5,3)

# %%
x
# Out:
#  0.8290  0.9822  0.3190
#  0.0210  0.1709  0.5356
#  0.0365  0.4655  0.8008
#  0.7458  0.9519  0.7001
#  0.5207  0.6929  0.8747
# [torch.FloatTensor of size 5x3]

# %%
x.size()
# Out:
# torch.Size([5, 3])

# %%
y = torch.rand(5,3)

# %% [markdown]
# 要素毎の加算

# %%
x+y
# Out:
#  1.3064  1.5927  0.3594
#  0.6163  1.0176  0.9933
#  1.0233  0.6604  1.6695
#  0.9467  1.3508  1.3941
#  1.2131  1.2213  1.0277
# [torch.FloatTensor of size 5x3]

# %%
torch.add(x,y)
# Out:
#  1.3064  1.5927  0.3594
#  0.6163  1.0176  0.9933
#  1.0233  0.6604  1.6695
#  0.9467  1.3508  1.3941
#  1.2131  1.2213  1.0277
# [torch.FloatTensor of size 5x3]

# %% [markdown]
# 要素積

# %%
x* y
# Out:
#  0.3958  0.5996  0.0129
#  0.0125  0.1447  0.2451
#  0.0360  0.0907  0.6956
#  0.1498  0.3797  0.4859
#  0.3605  0.3661  0.1338
# [torch.FloatTensor of size 5x3]

# %%
torch.mul(x,y)
# Out:
#  0.3958  0.5996  0.0129
#  0.0125  0.1447  0.2451
#  0.0360  0.0907  0.6956
#  0.1498  0.3797  0.4859
#  0.3605  0.3661  0.1338
# [torch.FloatTensor of size 5x3]

# %% [markdown]
# ただし.mmは要素積ではなく内積

# %%
torch.mm(x,y)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-3adfa0c9425b> in <module>()
# ----> 1 torch.mm(x,y)
#
# RuntimeError: size mismatch, m1: [5 x 3], m2: [5 x 3] at /py/conda-bld/pytorch_1493679085273/work/torch/lib/TH/generic/THTensorMath.c:1237

# %% [markdown]
# Tensorのスライスもできる

# %%
x[:,1]
# Out:
#  0.9822
#  0.1709
#  0.4655
#  0.9519
#  0.6929
# [torch.FloatTensor of size 5]

# %%
x[1,:]
# Out:
#  0.0210
#  0.1709
#  0.5356
# [torch.FloatTensor of size 3]

# %%
a = torch.ones(5)

# %%
a
# Out:
#  1
#  1
#  1
#  1
#  1
# [torch.FloatTensor of size 5]

# %% [markdown]
# 破壊的な変更を行う関数は後ろに_がつく

# %%
a.add_(1)
# Out:
#  2
#  2
#  2
#  2
#  2
# [torch.FloatTensor of size 5]

# %%
a.mul_(2)
# Out:
#  4
#  4
#  4
#  4
#  4
# [torch.FloatTensor of size 5]

# %% [markdown]
# ### .cudaでCuda.FloatTensor型にキャストできる

# %%
# let us run this cell only if CUDA is available
if torch.cuda.is_available():
    x = x.cuda()
    y = y.cuda()
    x + y

# %%
x
# Out:
#  0.8290  0.9822  0.3190
#  0.0210  0.1709  0.5356
#  0.0365  0.4655  0.8008
#  0.7458  0.9519  0.7001
#  0.5207  0.6929  0.8747
# [torch.cuda.FloatTensor of size 5x3 (GPU 0)]

# %%
y
# Out:
#  0.4774  0.6105  0.0404
#  0.5953  0.8466  0.4577
#  0.9868  0.1949  0.8686
#  0.2009  0.3989  0.6939
#  0.6924  0.5284  0.1529
# [torch.cuda.FloatTensor of size 5x3 (GPU 0)]
